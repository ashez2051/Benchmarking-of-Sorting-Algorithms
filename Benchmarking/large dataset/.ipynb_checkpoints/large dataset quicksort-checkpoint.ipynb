# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import timeit
import copy

# %%
pd.set_option('display.max_columns',192)
pd.set_option('display.max_rows',192)
pd.set_option('display.max_colwidth',-1)
plt.rcParams['figure.figsize']=(15,9)

# %%
import sys
print("System version:", sys.version)
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# System version: 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]
# Pandas version: 0.24.2
# NumPy version: 1.16.4

# %% [markdown]
# ## Quick Sort

# %%
def quicksort(A):
    _quicksort1(A, 0, len(A) - 1)
    return A

def partition(A, p, r):
    x = A[r]
    i = p - 1
    for j in range(p, r):
        if A[j] <= x:
            i += 1
            A[i], A[j] = A[j], A[i]
    A[i + 1], A[r] =  A[r], A[i + 1]
    return i + 1

def _quicksort1(A, p, r):
    if p < r:
        q = partition(A, p, r)
        _quicksort1(A, p, q - 1)
        _quicksort1(A, q + 1, r)

# %% [markdown]
# ## Benchmarking

# %%
np.random.seed(12345)
benchmark_results_quick = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['random','identical']:
    
    for input_size in range(1,7):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': quicksort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Quick sort minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
        
        
        for run_number in range(5):
            benchmark_results_quick = benchmark_results_quick.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Quicksort',
                                                          'time':t[run_number]/n_ar},
                                                             ignore_index=True)
# Out:
# Quick sort minimum time on random data of size 10^1: 2.2054269999999578e-05
# Quick sort minimum time on random data of size 10^2: 0.0002808589999999924
# Quick sort minimum time on random data of size 10^3: 0.005118486000000076
# Quick sort minimum time on random data of size 10^4: 0.06557702000000062
# Quick sort minimum time on random data of size 10^5: 0.8114684999999895

# %%
benchmark_results_quick.to_pickle("./benchmark_results_quick.pkl")

# %%
pd.read_pickle("./benchmark_results_quick.pkl")
# Out:
#    input ordering input size run number sorting algorithm          time
# 0   sorted         10         1          Quicksort         1.545636e-05
# 1   sorted         10         2          Quicksort         1.391525e-05
# 2   sorted         10         3          Quicksort         1.421673e-05
# 3   sorted         10         4          Quicksort         1.372158e-05
# 4   sorted         10         5          Quicksort         1.417066e-05
# 5   sorted         100        1          Quicksort         7.753490e-04
# 6   sorted         100        2          Quicksort         8.340150e-04
# 7   sorted         100        3          Quicksort         7.530912e-04
# 8   sorted         100        4          Quicksort         7.553540e-04
# 9   sorted         100        5          Quicksort         7.775670e-04
# 10  sorted         1000       1          Quicksort         7.598796e-02
# 11  sorted         1000       2          Quicksort         7.595706e-02
# 12  sorted         1000       3          Quicksort         7.795098e-02
# 13  sorted         1000       4          Quicksort         7.855380e-02
# 14  sorted         1000       5          Quicksort         8.186438e-02
# 15  reversed       10         1          Quicksort         1.247101e-05
# 16  reversed       10         2          Quicksort         1.206373e-05
# 17  reversed       10         3          Quicksort         1.156121e-05
# 18  reversed       10         4          Quicksort         1.156041e-05
# 19  reversed       10         5          Quicksort         1.198044e-05
# 20  reversed       100        1          Quicksort         5.245558e-04
# 21  reversed       100        2          Quicksort         5.615812e-04
# 22  reversed       100        3          Quicksort         5.325078e-04
# 23  reversed       100        4          Quicksort         5.618116e-04
# 24  reversed       100        5          Quicksort         5.246006e-04
# 25  reversed       1000       1          Quicksort         5.357000e-02
# 26  reversed       1000       2          Quicksort         5.527142e-02
# 27  reversed       1000       3          Quicksort         5.359522e-02
# 28  reversed       1000       4          Quicksort         5.386442e-02
# 29  reversed       1000       5          Quicksort         5.374098e-02
# 30  random         10         1          Quicksort         1.848179e-05
# 31  random         10         2          Quicksort         1.830173e-05
# 32  random         10         3          Quicksort         1.831985e-05
# 33  random         10         4          Quicksort         1.836969e-05
# 34  random         10         5          Quicksort         1.832092e-05
# 35  random         100        1          Quicksort         3.285241e-04
# 36  random         100        2          Quicksort         3.341183e-04
# 37  random         100        3          Quicksort         3.278497e-04
# 38  random         100        4          Quicksort         3.278568e-04
# 39  random         100        5          Quicksort         3.290056e-04
# 40  random         1000       1          Quicksort         6.222812e-03
# 41  random         1000       2          Quicksort         6.129158e-03
# 42  random         1000       3          Quicksort         6.146878e-03
# 43  random         1000       4          Quicksort         6.222792e-03
# 44  random         1000       5          Quicksort         6.136034e-03
# 45  identical      10         1          Quicksort         5.023594e-07
# 46  identical      10         2          Quicksort         4.866982e-07
# 47  identical      10         3          Quicksort         4.865700e-07
# 48  identical      10         4          Quicksort         4.874000e-07
# 49  identical      10         5          Quicksort         4.930370e-07
# 50  identical      100        1          Quicksort         4.942510e-07
# 51  identical      100        2          Quicksort         4.886210e-07
# 52  identical      100        3          Quicksort         4.886140e-07
# 53  identical      100        4          Quicksort         4.896510e-07
# 54  identical      100        5          Quicksort         5.033850e-07
# 55  identical      1000       1          Quicksort         4.870736e-07
# 56  identical      1000       2          Quicksort         4.870066e-07
# 57  identical      1000       3          Quicksort         4.873784e-07
# 58  identical      1000       4          Quicksort         4.871272e-07
# 59  identical      1000       5          Quicksort         5.025602e-07

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_quick, hue ='input ordering')

# %% [markdown]
# ## Heap Sort

# %%
# Python program for implementation of heap Sort 
  
# To heapify subtree rooted at index i. 
# n is size of heap 
def heapify(arr, n, i): 
    largest = i  # Initialize largest as root 
    l = 2 * i + 1     # left = 2*i + 1 
    r = 2 * i + 2     # right = 2*i + 2 
  
    # See if left child of root exists and is 
    # greater than root 
    if l < n and arr[i] < arr[l]: 
        largest = l 
  
    # See if right child of root exists and is 
    # greater than root 
    if r < n and arr[largest] < arr[r]: 
        largest = r 
  
    # Change root, if needed 
    if largest != i: 
        arr[i],arr[largest] = arr[largest],arr[i]  # swap 
  
        # Heapify the root. 
        heapify(arr, n, largest) 
        
## main function to sort given array       
def sort_heap(arr): 
    n = len(arr) 
  
    # Build a maxheap. 
    for i in range(n, -1, -1): 
        heapify(arr, n, i) 
  
    # One by one extract elements 
    for i in range(n-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i]   # swap 
        heapify(arr, i, 0) 
        
    return arr

# %% [markdown]
#  ## Benchmarking

# %%
np.random.seed(12345)
benchmark_results_heap = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,7):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': sort_heap,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Heap sort minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
       
        for run_number in range(5):
            benchmark_results_heap = benchmark_results_heap.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Heap Sort',
                                                          'time':t[run_number]/n_ar},
                                                        ignore_index=True)
# Out:
# Heap sort minimum time on sorted data of size 10^1: 1.681159999999995e-05
# Heap sort minimum time on sorted data of size 10^2: 0.00029292879999999856
# Heap sort minimum time on sorted data of size 10^3: 0.004565190000000001
# Heap sort minimum time on sorted data of size 10^4: 0.06289261999999951
# Heap sort minimum time on sorted data of size 10^5: 0.8069561000000007
# Heap sort minimum time on sorted data of size 10^6: 10.000247700000003
# Heap sort minimum time on reversed data of size 10^1: 1.26628249999996e-05
# Heap sort minimum time on reversed data of size 10^2: 0.0002467043999999987
# Heap sort minimum time on reversed data of size 10^3: 0.003934817999999893
# Heap sort minimum time on reversed data of size 10^4: 0.056689240000000043
# Heap sort minimum time on reversed data of size 10^5: 0.9746102000000008
# Heap sort minimum time on reversed data of size 10^6: 9.48413069999998
# Heap sort minimum time on random data of size 10^1: 4.241885000000139e-05
# Heap sort minimum time on random data of size 10^2: 0.0007138749999999732
# Heap sort minimum time on random data of size 10^3: 0.011319120000000283
# Heap sort minimum time on random data of size 10^4: 0.15811089999999695
# Heap sort minimum time on random data of size 10^5: 1.9983346999999867
# Heap sort minimum time on random data of size 10^6: 24.509469499999966
# Heap sort minimum time on identical data of size 10^1: 1.1541010000001962e-06
# Heap sort minimum time on identical data of size 10^2: 1.1546835000001465e-06
# Heap sort minimum time on identical data of size 10^3: 1.3832714999998074e-06
# Heap sort minimum time on identical data of size 10^4: 1.154784999999947e-06
# Heap sort minimum time on identical data of size 10^5: 1.1546125000000984e-06
# Heap sort minimum time on identical data of size 10^6: 1.1557709999999588e-06

# %%
benchmark_results_heap.to_pickle("./benchmark_results_heap.pkl")

# %%
pd.read_pickle("./benchmark_results_heap.pkl")
# Out:
#     input ordering input size run number sorting algorithm       time
# 0    sorted         10         1          Heap Sort         0.000018
# 1    sorted         10         2          Heap Sort         0.000023
# 2    sorted         10         3          Heap Sort         0.000021
# 3    sorted         10         4          Heap Sort         0.000020
# 4    sorted         10         5          Heap Sort         0.000017
# 5    sorted         100        1          Heap Sort         0.000301
# 6    sorted         100        2          Heap Sort         0.000293
# 7    sorted         100        3          Heap Sort         0.000293
# 8    sorted         100        4          Heap Sort         0.000298
# 9    sorted         100        5          Heap Sort         0.000294
# 10   sorted         1000       1          Heap Sort         0.004776
# 11   sorted         1000       2          Heap Sort         0.004780
# 12   sorted         1000       3          Heap Sort         0.004937
# 13   sorted         1000       4          Heap Sort         0.004769
# 14   sorted         1000       5          Heap Sort         0.004565
# 15   sorted         10000      1          Heap Sort         0.065494
# 16   sorted         10000      2          Heap Sort         0.063215
# 17   sorted         10000      3          Heap Sort         0.064849
# 18   sorted         10000      4          Heap Sort         0.062893
# 19   sorted         10000      5          Heap Sort         0.063056
# 20   sorted         100000     1          Heap Sort         1.074641
# 21   sorted         100000     2          Heap Sort         0.815713
# 22   sorted         100000     3          Heap Sort         0.824355
# 23   sorted         100000     4          Heap Sort         0.816525
# 24   sorted         100000     5          Heap Sort         0.806956
# 25   sorted         1000000    1          Heap Sort         10.123866
# 26   sorted         1000000    2          Heap Sort         10.012444
# 27   sorted         1000000    3          Heap Sort         10.028608
# 28   sorted         1000000    4          Heap Sort         10.017693
# 29   sorted         1000000    5          Heap Sort         10.000248
# 30   reversed       10         1          Heap Sort         0.000013
# 31   reversed       10         2          Heap Sort         0.000013
# 32   reversed       10         3          Heap Sort         0.000013
# 33   reversed       10         4          Heap Sort         0.000013
# 34   reversed       10         5          Heap Sort         0.000014
# 35   reversed       100        1          Heap Sort         0.000247
# 36   reversed       100        2          Heap Sort         0.000256
# 37   reversed       100        3          Heap Sort         0.000247
# 38   reversed       100        4          Heap Sort         0.000247
# 39   reversed       100        5          Heap Sort         0.000256
# 40   reversed       1000       1          Heap Sort         0.004026
# 41   reversed       1000       2          Heap Sort         0.003959
# 42   reversed       1000       3          Heap Sort         0.003935
# 43   reversed       1000       4          Heap Sort         0.003941
# 44   reversed       1000       5          Heap Sort         0.004041
# 45   reversed       10000      1          Heap Sort         0.056689
# 46   reversed       10000      2          Heap Sort         0.056934
# 47   reversed       10000      3          Heap Sort         0.056943
# 48   reversed       10000      4          Heap Sort         0.056917
# 49   reversed       10000      5          Heap Sort         0.056941
# 50   reversed       100000     1          Heap Sort         1.018156
# 51   reversed       100000     2          Heap Sort         0.974610
# 52   reversed       100000     3          Heap Sort         0.974930
# 53   reversed       100000     4          Heap Sort         0.997037
# 54   reversed       100000     5          Heap Sort         0.989707
# 55   reversed       1000000    1          Heap Sort         11.411290
# 56   reversed       1000000    2          Heap Sort         11.838919
# 57   reversed       1000000    3          Heap Sort         10.039850
# 58   reversed       1000000    4          Heap Sort         9.524816
# 59   reversed       1000000    5          Heap Sort         9.484131
# 60   random         10         1          Heap Sort         0.000043
# 61   random         10         2          Heap Sort         0.000044
# 62   random         10         3          Heap Sort         0.000042
# 63   random         10         4          Heap Sort         0.000043
# 64   random         10         5          Heap Sort         0.000042
# 65   random         100        1          Heap Sort         0.000714
# 66   random         100        2          Heap Sort         0.000719
# 67   random         100        3          Heap Sort         0.000718
# 68   random         100        4          Heap Sort         0.000718
# 69   random         100        5          Heap Sort         0.000723
# 70   random         1000       1          Heap Sort         0.011690
# 71   random         1000       2          Heap Sort         0.011485
# 72   random         1000       3          Heap Sort         0.011562
# 73   random         1000       4          Heap Sort         0.011561
# 74   random         1000       5          Heap Sort         0.011319
# 75   random         10000      1          Heap Sort         0.162318
# 76   random         10000      2          Heap Sort         0.158127
# 77   random         10000      3          Heap Sort         0.158153
# 78   random         10000      4          Heap Sort         0.158111
# 79   random         10000      5          Heap Sort         0.160613
# 80   random         100000     1          Heap Sort         2.009663
# 81   random         100000     2          Heap Sort         2.008334
# 82   random         100000     3          Heap Sort         2.137779
# 83   random         100000     4          Heap Sort         1.998335
# 84   random         100000     5          Heap Sort         2.004607
# 85   random         1000000    1          Heap Sort         24.803301
# 86   random         1000000    2          Heap Sort         26.198088
# 87   random         1000000    3          Heap Sort         24.509469
# 88   random         1000000    4          Heap Sort         24.605474
# 89   random         1000000    5          Heap Sort         24.580200
# 90   identical      10         1          Heap Sort         0.000001
# 91   identical      10         2          Heap Sort         0.000001
# 92   identical      10         3          Heap Sort         0.000001
# 93   identical      10         4          Heap Sort         0.000001
# 94   identical      10         5          Heap Sort         0.000001
# 95   identical      100        1          Heap Sort         0.000001
# 96   identical      100        2          Heap Sort         0.000001
# 97   identical      100        3          Heap Sort         0.000001
# 98   identical      100        4          Heap Sort         0.000001
# 99   identical      100        5          Heap Sort         0.000001
# 100  identical      1000       1          Heap Sort         0.000001
# 101  identical      1000       2          Heap Sort         0.000001
# 102  identical      1000       3          Heap Sort         0.000002
# 103  identical      1000       4          Heap Sort         0.000001
# 104  identical      1000       5          Heap Sort         0.000002
# 105  identical      10000      1          Heap Sort         0.000001
# 106  identical      10000      2          Heap Sort         0.000001
# 107  identical      10000      3          Heap Sort         0.000001
# 108  identical      10000      4          Heap Sort         0.000001
# 109  identical      10000      5          Heap Sort         0.000001
# 110  identical      100000     1          Heap Sort         0.000001
# 111  identical      100000     2          Heap Sort         0.000001
# 112  identical      100000     3          Heap Sort         0.000001
# 113  identical      100000     4          Heap Sort         0.000001
# 114  identical      100000     5          Heap Sort         0.000001
# 115  identical      1000000    1          Heap Sort         0.000001
# 116  identical      1000000    2          Heap Sort         0.000001
# 117  identical      1000000    3          Heap Sort         0.000001
# 118  identical      1000000    4          Heap Sort         0.000001
# 119  identical      1000000    5          Heap Sort         0.000001

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_heap, hue ='input ordering')

# %% [markdown]
# ## Merge Sort

# %%
def merge_sort(data):
   
    if len(data) > 1:
        
        mid = int(len(data)/2)
        lefthalf = data[:mid]
        righthalf = data[mid:]
        
        merge_sort(lefthalf)
        merge_sort(righthalf)
        
        i=0
        j=0
        k=0
        
        while i<len(lefthalf) and j<len(righthalf):
            
            if lefthalf[i]<righthalf[j]:
                data[k] = lefthalf[i]
                
                i+=1
                
            else:
                data[k]= righthalf[j]
                j+=1
                
            k+=1
            
        while i<len(lefthalf):
            data[k] = lefthalf[i]
            i+=1
            k+=1
            
        while j<len(righthalf):
            data[k] = righthalf[j]
            j= j+1
            k= k+1
            
        return data

# %%
np.random.seed(12345)
benchmark_results_merge = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,7):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': merge_sort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Merge Sort minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
        
        
        for run_number in range(5):
            benchmark_results_merge = benchmark_results_merge.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Merge Sort',
                                                          'time':t[run_number]/n_ar},
                                                        ignore_index=True)
# Out:
# Merge Sort minimum time on sorted data of size 10^1: 1.6278360000001156e-05
# Merge Sort minimum time on sorted data of size 10^2: 0.0002217573000000357
# Merge Sort minimum time on sorted data of size 10^3: 0.0029269319999997378
# Merge Sort minimum time on sorted data of size 10^4: 0.038471359999999774
# Merge Sort minimum time on sorted data of size 10^5: 0.4758669999999938
# Merge Sort minimum time on sorted data of size 10^6: 6.273961899999961
# Merge Sort minimum time on reversed data of size 10^1: 1.6433490000000007e-05
# Merge Sort minimum time on reversed data of size 10^2: 0.00023232550000000174
# Merge Sort minimum time on reversed data of size 10^3: 0.002985171000000264
# Merge Sort minimum time on reversed data of size 10^4: 0.038706500000000685
# Merge Sort minimum time on reversed data of size 10^5: 0.47600390000002335
# Merge Sort minimum time on reversed data of size 10^6: 6.615099999999984
# Merge Sort minimum time on random data of size 10^1: 2.8457349999996496e-05
# Merge Sort minimum time on random data of size 10^2: 0.0004780021999999917
# Merge Sort minimum time on random data of size 10^3: 0.0067123519999995555
# Merge Sort minimum time on random data of size 10^4: 0.08712713999999551
# Merge Sort minimum time on random data of size 10^5: 1.0965934999999831
# Merge Sort minimum time on random data of size 10^6: 12.801821899999936
# Merge Sort minimum time on identical data of size 10^1: 4.0449499999999716e-07
# Merge Sort minimum time on identical data of size 10^2: 4.053409999999076e-07
# Merge Sort minimum time on identical data of size 10^3: 4.042242000000442e-07
# Merge Sort minimum time on identical data of size 10^4: 4.0435500000012327e-07
# Merge Sort minimum time on identical data of size 10^5: 4.0454320000003463e-07
# Merge Sort minimum time on identical data of size 10^6: 4.0499720000002525e-07

# %%
benchmark_results_merge.to_pickle("./benchmark_results_merge.pkl")

# %%
pd.read_pickle("./benchmark_results_merge.pkl")
# Out:
#     input ordering input size run number sorting algorithm          time
# 0    sorted         10         1          Merge Sort        1.627836e-05
# 1    sorted         10         2          Merge Sort        2.110944e-05
# 2    sorted         10         3          Merge Sort        2.036687e-05
# 3    sorted         10         4          Merge Sort        2.026609e-05
# 4    sorted         10         5          Merge Sort        2.018794e-05
# 5    sorted         100        1          Merge Sort        2.218562e-04
# 6    sorted         100        2          Merge Sort        2.217573e-04
# 7    sorted         100        3          Merge Sort        2.217860e-04
# 8    sorted         100        4          Merge Sort        2.300631e-04
# 9    sorted         100        5          Merge Sort        2.220095e-04
# 10   sorted         1000       1          Merge Sort        2.944327e-03
# 11   sorted         1000       2          Merge Sort        2.928238e-03
# 12   sorted         1000       3          Merge Sort        2.926932e-03
# 13   sorted         1000       4          Merge Sort        3.049811e-03
# 14   sorted         1000       5          Merge Sort        2.990346e-03
# 15   sorted         10000      1          Merge Sort        3.848766e-02
# 16   sorted         10000      2          Merge Sort        3.918030e-02
# 17   sorted         10000      3          Merge Sort        3.847136e-02
# 18   sorted         10000      4          Merge Sort        3.891435e-02
# 19   sorted         10000      5          Merge Sort        3.886840e-02
# 20   sorted         100000     1          Merge Sort        4.808213e-01
# 21   sorted         100000     2          Merge Sort        4.758670e-01
# 22   sorted         100000     3          Merge Sort        4.920925e-01
# 23   sorted         100000     4          Merge Sort        4.990586e-01
# 24   sorted         100000     5          Merge Sort        4.935466e-01
# 25   sorted         1000000    1          Merge Sort        6.785499e+00
# 26   sorted         1000000    2          Merge Sort        6.572416e+00
# 27   sorted         1000000    3          Merge Sort        6.312896e+00
# 28   sorted         1000000    4          Merge Sort        6.330814e+00
# 29   sorted         1000000    5          Merge Sort        6.273962e+00
# 30   reversed       10         1          Merge Sort        1.643349e-05
# 31   reversed       10         2          Merge Sort        1.660953e-05
# 32   reversed       10         3          Merge Sort        1.646590e-05
# 33   reversed       10         4          Merge Sort        1.682283e-05
# 34   reversed       10         5          Merge Sort        1.645043e-05
# 35   reversed       100        1          Merge Sort        2.323255e-04
# 36   reversed       100        2          Merge Sort        2.360032e-04
# 37   reversed       100        3          Merge Sort        2.402336e-04
# 38   reversed       100        4          Merge Sort        2.327227e-04
# 39   reversed       100        5          Merge Sort        2.323639e-04
# 40   reversed       1000       1          Merge Sort        2.986948e-03
# 41   reversed       1000       2          Merge Sort        2.985171e-03
# 42   reversed       1000       3          Merge Sort        3.083277e-03
# 43   reversed       1000       4          Merge Sort        3.105899e-03
# 44   reversed       1000       5          Merge Sort        2.986484e-03
# 45   reversed       10000      1          Merge Sort        3.912162e-02
# 46   reversed       10000      2          Merge Sort        3.870650e-02
# 47   reversed       10000      3          Merge Sort        3.871554e-02
# 48   reversed       10000      4          Merge Sort        3.871562e-02
# 49   reversed       10000      5          Merge Sort        3.941440e-02
# 50   reversed       100000     1          Merge Sort        4.780549e-01
# 51   reversed       100000     2          Merge Sort        4.760039e-01
# 52   reversed       100000     3          Merge Sort        4.927269e-01
# 53   reversed       100000     4          Merge Sort        4.768602e-01
# 54   reversed       100000     5          Merge Sort        4.845917e-01
# 55   reversed       1000000    1          Merge Sort        6.700849e+00
# 56   reversed       1000000    2          Merge Sort        6.623993e+00
# 57   reversed       1000000    3          Merge Sort        6.723763e+00
# 58   reversed       1000000    4          Merge Sort        6.615100e+00
# 59   reversed       1000000    5          Merge Sort        6.652533e+00
# 60   random         10         1          Merge Sort        2.856333e-05
# 61   random         10         2          Merge Sort        3.753443e-05
# 62   random         10         3          Merge Sort        2.845735e-05
# 63   random         10         4          Merge Sort        2.853599e-05
# 64   random         10         5          Merge Sort        2.850493e-05
# 65   random         100        1          Merge Sort        4.826630e-04
# 66   random         100        2          Merge Sort        4.780162e-04
# 67   random         100        3          Merge Sort        4.787352e-04
# 68   random         100        4          Merge Sort        4.780022e-04
# 69   random         100        5          Merge Sort        4.879680e-04
# 70   random         1000       1          Merge Sort        6.790264e-03
# 71   random         1000       2          Merge Sort        6.733724e-03
# 72   random         1000       3          Merge Sort        6.734484e-03
# 73   random         1000       4          Merge Sort        6.712352e-03
# 74   random         1000       5          Merge Sort        6.720956e-03
# 75   random         10000      1          Merge Sort        8.876250e-02
# 76   random         10000      2          Merge Sort        8.722262e-02
# 77   random         10000      3          Merge Sort        8.717550e-02
# 78   random         10000      4          Merge Sort        8.828794e-02
# 79   random         10000      5          Merge Sort        8.712714e-02
# 80   random         100000     1          Merge Sort        1.098167e+00
# 81   random         100000     2          Merge Sort        1.096678e+00
# 82   random         100000     3          Merge Sort        1.096970e+00
# 83   random         100000     4          Merge Sort        1.096593e+00
# 84   random         100000     5          Merge Sort        1.100627e+00
# 85   random         1000000    1          Merge Sort        1.390481e+01
# 86   random         1000000    2          Merge Sort        1.342059e+01
# 87   random         1000000    3          Merge Sort        1.280182e+01
# 88   random         1000000    4          Merge Sort        1.373804e+01
# 89   random         1000000    5          Merge Sort        1.280749e+01
# 90   identical      10         1          Merge Sort        4.047280e-07
# 91   identical      10         2          Merge Sort        4.044950e-07
# 92   identical      10         3          Merge Sort        4.048442e-07
# 93   identical      10         4          Merge Sort        4.046958e-07
# 94   identical      10         5          Merge Sort        4.046896e-07
# 95   identical      100        1          Merge Sort        4.056886e-07
# 96   identical      100        2          Merge Sort        4.054408e-07
# 97   identical      100        3          Merge Sort        4.053410e-07
# 98   identical      100        4          Merge Sort        4.053664e-07
# 99   identical      100        5          Merge Sort        4.056906e-07
# 100  identical      1000       1          Merge Sort        4.045520e-07
# 101  identical      1000       2          Merge Sort        4.042242e-07
# 102  identical      1000       3          Merge Sort        4.196012e-07
# 103  identical      1000       4          Merge Sort        4.044340e-07
# 104  identical      1000       5          Merge Sort        4.043746e-07
# 105  identical      10000      1          Merge Sort        4.046520e-07
# 106  identical      10000      2          Merge Sort        4.043550e-07
# 107  identical      10000      3          Merge Sort        4.043734e-07
# 108  identical      10000      4          Merge Sort        4.043720e-07
# 109  identical      10000      5          Merge Sort        4.044760e-07
# 110  identical      100000     1          Merge Sort        4.047396e-07
# 111  identical      100000     2          Merge Sort        4.046896e-07
# 112  identical      100000     3          Merge Sort        4.045432e-07
# 113  identical      100000     4          Merge Sort        4.048434e-07
# 114  identical      100000     5          Merge Sort        4.048638e-07
# 115  identical      1000000    1          Merge Sort        4.054318e-07
# 116  identical      1000000    2          Merge Sort        4.049972e-07
# 117  identical      1000000    3          Merge Sort        4.053250e-07
# 118  identical      1000000    4          Merge Sort        4.055086e-07
# 119  identical      1000000    5          Merge Sort        4.061162e-07

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_merge, hue ='input ordering')

# %% [markdown]
# ### Benchmarking of python sort function

# %%
np.random.seed(12345)
benchmark_results_python = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,7):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': sorted,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Python sort function minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
        
        for run_number in range(5):
            benchmark_results_python = benchmark_results_python.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Python Sort',
                                                          'time':t[run_number]/n_ar},
                                                             ignore_index=True)
# Out:
# Python sort function minimum time on sorted data of size 10^1: 6.823589999999058e-07
# Python sort function minimum time on sorted data of size 10^2: 2.9043690000003154e-06
# Python sort function minimum time on sorted data of size 10^3: 2.3778200000003834e-05
# Python sort function minimum time on sorted data of size 10^4: 0.00025291790000005676
# Python sort function minimum time on sorted data of size 10^5: 0.0030826909999996134
# Python sort function minimum time on sorted data of size 10^6: 0.1287988999999925
# Python sort function minimum time on reversed data of size 10^1: 6.885830000001079e-07
# Python sort function minimum time on reversed data of size 10^2: 2.8359579999994364e-06
# Python sort function minimum time on reversed data of size 10^3: 2.3103100000002998e-05
# Python sort function minimum time on reversed data of size 10^4: 0.00024753180000004705
# Python sort function minimum time on reversed data of size 10^5: 0.0030040440000004766
# Python sort function minimum time on reversed data of size 10^6: 0.12937130000000252
# Python sort function minimum time on random data of size 10^1: 3.0511990000002243e-06
# Python sort function minimum time on random data of size 10^2: 2.2906399999999395e-05
# Python sort function minimum time on random data of size 10^3: 0.0003051077999999734
# Python sort function minimum time on random data of size 10^4: 0.0038839710000002016
# Python sort function minimum time on random data of size 10^5: 0.049836159999995286
# Python sort function minimum time on random data of size 10^6: 0.7636899000000312
# Python sort function minimum time on identical data of size 10^1: 3.955860000000939e-07
# Python sort function minimum time on identical data of size 10^2: 3.953977999999552e-07
# Python sort function minimum time on identical data of size 10^3: 3.9527139999995597e-07
# Python sort function minimum time on identical data of size 10^4: 3.9578779999988e-07
# Python sort function minimum time on identical data of size 10^5: 3.954186000000846e-07
# Python sort function minimum time on identical data of size 10^6: 3.9507240000011734e-07

# %%
benchmark_results_python.to_pickle("./benchmark_results_python.pkl")

# %%
pd.read_pickle("./benchmark_results_python.pkl")
# Out:
#     input ordering input size run number sorting algorithm          time
# 0    sorted         10         1          Python Sort       6.883962e-07
# 1    sorted         10         2          Python Sort       7.315646e-07
# 2    sorted         10         3          Python Sort       6.919138e-07
# 3    sorted         10         4          Python Sort       6.912934e-07
# 4    sorted         10         5          Python Sort       6.823590e-07
# 5    sorted         100        1          Python Sort       2.936621e-06
# 6    sorted         100        2          Python Sort       2.984569e-06
# 7    sorted         100        3          Python Sort       2.904369e-06
# 8    sorted         100        4          Python Sort       2.913735e-06
# 9    sorted         100        5          Python Sort       2.905791e-06
# 10   sorted         1000       1          Python Sort       2.378813e-05
# 11   sorted         1000       2          Python Sort       2.380413e-05
# 12   sorted         1000       3          Python Sort       2.384280e-05
# 13   sorted         1000       4          Python Sort       2.379801e-05
# 14   sorted         1000       5          Python Sort       2.377820e-05
# 15   sorted         10000      1          Python Sort       2.534280e-04
# 16   sorted         10000      2          Python Sort       2.536862e-04
# 17   sorted         10000      3          Python Sort       2.532081e-04
# 18   sorted         10000      4          Python Sort       2.529179e-04
# 19   sorted         10000      5          Python Sort       2.530189e-04
# 20   sorted         100000     1          Python Sort       3.130540e-03
# 21   sorted         100000     2          Python Sort       3.082691e-03
# 22   sorted         100000     3          Python Sort       3.117670e-03
# 23   sorted         100000     4          Python Sort       3.093391e-03
# 24   sorted         100000     5          Python Sort       3.137036e-03
# 25   sorted         1000000    1          Python Sort       1.325038e-01
# 26   sorted         1000000    2          Python Sort       1.288782e-01
# 27   sorted         1000000    3          Python Sort       1.287989e-01
# 28   sorted         1000000    4          Python Sort       1.372342e-01
# 29   sorted         1000000    5          Python Sort       1.288038e-01
# 30   reversed       10         1          Python Sort       7.164068e-07
# 31   reversed       10         2          Python Sort       7.032822e-07
# 32   reversed       10         3          Python Sort       6.986926e-07
# 33   reversed       10         4          Python Sort       6.895322e-07
# 34   reversed       10         5          Python Sort       6.885830e-07
# 35   reversed       100        1          Python Sort       2.835958e-06
# 36   reversed       100        2          Python Sort       2.850560e-06
# 37   reversed       100        3          Python Sort       3.325355e-06
# 38   reversed       100        4          Python Sort       2.880979e-06
# 39   reversed       100        5          Python Sort       2.839183e-06
# 40   reversed       1000       1          Python Sort       2.316686e-05
# 41   reversed       1000       2          Python Sort       2.310310e-05
# 42   reversed       1000       3          Python Sort       2.312306e-05
# 43   reversed       1000       4          Python Sort       2.332340e-05
# 44   reversed       1000       5          Python Sort       2.339517e-05
# 45   reversed       10000      1          Python Sort       2.477646e-04
# 46   reversed       10000      2          Python Sort       2.523292e-04
# 47   reversed       10000      3          Python Sort       2.475318e-04
# 48   reversed       10000      4          Python Sort       2.476646e-04
# 49   reversed       10000      5          Python Sort       2.499844e-04
# 50   reversed       100000     1          Python Sort       3.004044e-03
# 51   reversed       100000     2          Python Sort       3.051909e-03
# 52   reversed       100000     3          Python Sort       3.026051e-03
# 53   reversed       100000     4          Python Sort       3.008177e-03
# 54   reversed       100000     5          Python Sort       3.012183e-03
# 55   reversed       1000000    1          Python Sort       1.298248e-01
# 56   reversed       1000000    2          Python Sort       1.293713e-01
# 57   reversed       1000000    3          Python Sort       1.296237e-01
# 58   reversed       1000000    4          Python Sort       1.294501e-01
# 59   reversed       1000000    5          Python Sort       1.294198e-01
# 60   random         10         1          Python Sort       3.051199e-06
# 61   random         10         2          Python Sort       3.079917e-06
# 62   random         10         3          Python Sort       3.097272e-06
# 63   random         10         4          Python Sort       3.058258e-06
# 64   random         10         5          Python Sort       3.061518e-06
# 65   random         100        1          Python Sort       2.329449e-05
# 66   random         100        2          Python Sort       2.290640e-05
# 67   random         100        3          Python Sort       2.313286e-05
# 68   random         100        4          Python Sort       2.294160e-05
# 69   random         100        5          Python Sort       2.292070e-05
# 70   random         1000       1          Python Sort       3.065738e-04
# 71   random         1000       2          Python Sort       3.051078e-04
# 72   random         1000       3          Python Sort       3.067594e-04
# 73   random         1000       4          Python Sort       3.092134e-04
# 74   random         1000       5          Python Sort       3.051329e-04
# 75   random         10000      1          Python Sort       3.890498e-03
# 76   random         10000      2          Python Sort       3.921294e-03
# 77   random         10000      3          Python Sort       3.884254e-03
# 78   random         10000      4          Python Sort       3.883971e-03
# 79   random         10000      5          Python Sort       3.923954e-03
# 80   random         100000     1          Python Sort       4.983616e-02
# 81   random         100000     2          Python Sort       5.062016e-02
# 82   random         100000     3          Python Sort       4.993044e-02
# 83   random         100000     4          Python Sort       4.987548e-02
# 84   random         100000     5          Python Sort       4.997654e-02
# 85   random         1000000    1          Python Sort       8.233355e-01
# 86   random         1000000    2          Python Sort       7.636899e-01
# 87   random         1000000    3          Python Sort       7.729756e-01
# 88   random         1000000    4          Python Sort       7.989999e-01
# 89   random         1000000    5          Python Sort       8.264675e-01
# 90   identical      10         1          Python Sort       3.957030e-07
# 91   identical      10         2          Python Sort       4.081652e-07
# 92   identical      10         3          Python Sort       3.955860e-07
# 93   identical      10         4          Python Sort       4.224788e-07
# 94   identical      10         5          Python Sort       4.104002e-07
# 95   identical      100        1          Python Sort       3.953978e-07
# 96   identical      100        2          Python Sort       3.954114e-07
# 97   identical      100        3          Python Sort       3.956278e-07
# 98   identical      100        4          Python Sort       3.954092e-07
# 99   identical      100        5          Python Sort       3.954664e-07
# 100  identical      1000       1          Python Sort       4.128062e-07
# 101  identical      1000       2          Python Sort       3.954084e-07
# 102  identical      1000       3          Python Sort       4.115204e-07
# 103  identical      1000       4          Python Sort       3.952714e-07
# 104  identical      1000       5          Python Sort       3.957686e-07
# 105  identical      10000      1          Python Sort       4.088120e-07
# 106  identical      10000      2          Python Sort       3.957878e-07
# 107  identical      10000      3          Python Sort       4.729060e-07
# 108  identical      10000      4          Python Sort       4.209416e-07
# 109  identical      10000      5          Python Sort       5.415132e-07
# 110  identical      100000     1          Python Sort       3.954186e-07
# 111  identical      100000     2          Python Sort       3.955832e-07
# 112  identical      100000     3          Python Sort       3.958622e-07
# 113  identical      100000     4          Python Sort       4.082994e-07
# 114  identical      100000     5          Python Sort       3.954736e-07
# 115  identical      1000000    1          Python Sort       4.087214e-07
# 116  identical      1000000    2          Python Sort       3.951698e-07
# 117  identical      1000000    3          Python Sort       3.951132e-07
# 118  identical      1000000    4          Python Sort       3.950724e-07
# 119  identical      1000000    5          Python Sort       4.257486e-07

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_python, hue ='input ordering')

# %% [markdown]
# ## Numpy Sort

# %%
def numpy_sort(data):
    return np.sort(data)

# %%
np.random.seed(12345)
benchmark_results_numpy = pd.DataFrame(columns =['input ordering','input size', 'sorting algorithm','time'])

# %%
list_min_times = []

for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,7):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': numpy_sort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)
        min_time = min(t)/n_ar
        list_min_times.append(min_time)
        
        print(f"Numpy sort function minimum time on {input_ordering} data of size 10^{input_size}:", min_time)
        
        benchmark_results_numpy = benchmark_results_numpy.append({'input ordering': input_ordering,
                                                     'input size':10**input_size,
                                                      'sorting algorithm':'NumPy-sort',
                                                      'time':min_time},
                                                         ignore_index=True)
# Out:
# Numpy sort function minimum time on sorted data of size 10^1: 4.121696000001975e-06
# Numpy sort function minimum time on sorted data of size 10^2: 1.0481059999995068e-05
# Numpy sort function minimum time on sorted data of size 10^3: 7.044675999998162e-05
# Numpy sort function minimum time on sorted data of size 10^4: 0.0006955560000001242
# Numpy sort function minimum time on sorted data of size 10^5: 0.008920972000000802
# Numpy sort function minimum time on sorted data of size 10^6: 0.24986349999994673
# Numpy sort function minimum time on reversed data of size 10^1: 4.137524000000212e-06
# Numpy sort function minimum time on reversed data of size 10^2: 1.0296925000000101e-05
# Numpy sort function minimum time on reversed data of size 10^3: 7.359462000001713e-05
# Numpy sort function minimum time on reversed data of size 10^4: 0.0007378756000000522
# Numpy sort function minimum time on reversed data of size 10^5: 0.009221524000001863
# Numpy sort function minimum time on reversed data of size 10^6: 0.2490684000000556
# Numpy sort function minimum time on random data of size 10^1: 3.082669000000351e-06
# Numpy sort function minimum time on random data of size 10^2: 3.7790679999989153e-06
# Numpy sort function minimum time on random data of size 10^3: 3.138341000000082e-05
# Numpy sort function minimum time on random data of size 10^4: 0.0005055588000000171
# Numpy sort function minimum time on random data of size 10^5: 0.006344951999999467
# Numpy sort function minimum time on random data of size 10^6: 0.08147965000000568
# Numpy sort function minimum time on identical data of size 10^1: 3.1400629999996e-06
# Numpy sort function minimum time on identical data of size 10^2: 3.1289289999995163e-06
# Numpy sort function minimum time on identical data of size 10^3: 3.1323580000002947e-06
# Numpy sort function minimum time on identical data of size 10^4: 3.0845419999991464e-06
# Numpy sort function minimum time on identical data of size 10^5: 3.148371000000907e-06
# Numpy sort function minimum time on identical data of size 10^6: 3.1228880000003302e-06

# %%
benchmark_results_numpy.to_pickle("./benchmark_results_numpy.pkl")

# %%
pd.read_pickle("./benchmark_results_numpy.pkl")
# Out:
#    input ordering input size sorting algorithm      time
# 0   sorted         10         NumPy-sort        0.000004
# 1   sorted         100        NumPy-sort        0.000010
# 2   sorted         1000       NumPy-sort        0.000070
# 3   sorted         10000      NumPy-sort        0.000696
# 4   sorted         100000     NumPy-sort        0.008921
# 5   sorted         1000000    NumPy-sort        0.249863
# 6   reversed       10         NumPy-sort        0.000004
# 7   reversed       100        NumPy-sort        0.000010
# 8   reversed       1000       NumPy-sort        0.000074
# 9   reversed       10000      NumPy-sort        0.000738
# 10  reversed       100000     NumPy-sort        0.009222
# 11  reversed       1000000    NumPy-sort        0.249068
# 12  random         10         NumPy-sort        0.000003
# 13  random         100        NumPy-sort        0.000004
# 14  random         1000       NumPy-sort        0.000031
# 15  random         10000      NumPy-sort        0.000506
# 16  random         100000     NumPy-sort        0.006345
# 17  random         1000000    NumPy-sort        0.081480
# 18  identical      10         NumPy-sort        0.000003
# 19  identical      100        NumPy-sort        0.000003
# 20  identical      1000       NumPy-sort        0.000003
# 21  identical      10000      NumPy-sort        0.000003
# 22  identical      100000     NumPy-sort        0.000003
# 23  identical      1000000    NumPy-sort        0.000003

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_python, hue ='input ordering')

# %% [markdown]
# # Combined Dataframe

# %%
frames = [ benchmark_results_heap, benchmark_results_merge, benchmark_results_numpy, benchmark_results_python, benchmark_results_quick]

# %%
combined = pd.concat(frames, axis =0)
# Out:
# C:\Users\Ashesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
combined
# Out:
#     input ordering input size run number sorting algorithm          time
# 0    sorted         10         1          Heap Sort         1.771354e-05
# 1    sorted         10         2          Heap Sort         2.327142e-05
# 2    sorted         10         3          Heap Sort         2.134281e-05
# 3    sorted         10         4          Heap Sort         2.038003e-05
# 4    sorted         10         5          Heap Sort         1.681160e-05
# 5    sorted         100        1          Heap Sort         3.005371e-04
# 6    sorted         100        2          Heap Sort         2.929288e-04
# 7    sorted         100        3          Heap Sort         2.932095e-04
# 8    sorted         100        4          Heap Sort         2.978879e-04
# 9    sorted         100        5          Heap Sort         2.936115e-04
# 10   sorted         1000       1          Heap Sort         4.776066e-03
# 11   sorted         1000       2          Heap Sort         4.779546e-03
# 12   sorted         1000       3          Heap Sort         4.937474e-03
# 13   sorted         1000       4          Heap Sort         4.768794e-03
# 14   sorted         1000       5          Heap Sort         4.565190e-03
# 15   sorted         10000      1          Heap Sort         6.549416e-02
# 16   sorted         10000      2          Heap Sort         6.321482e-02
# 17   sorted         10000      3          Heap Sort         6.484914e-02
# 18   sorted         10000      4          Heap Sort         6.289262e-02
# 19   sorted         10000      5          Heap Sort         6.305608e-02
# 20   sorted         100000     1          Heap Sort         1.074641e+00
# 21   sorted         100000     2          Heap Sort         8.157131e-01
# 22   sorted         100000     3          Heap Sort         8.243548e-01
# 23   sorted         100000     4          Heap Sort         8.165248e-01
# 24   sorted         100000     5          Heap Sort         8.069561e-01
# 25   sorted         1000000    1          Heap Sort         1.012387e+01
# 26   sorted         1000000    2          Heap Sort         1.001244e+01
# 27   sorted         1000000    3          Heap Sort         1.002861e+01
# 28   sorted         1000000    4          Heap Sort         1.001769e+01
# 29   sorted         1000000    5          Heap Sort         1.000025e+01
# 30   reversed       10         1          Heap Sort         1.266282e-05
# 31   reversed       10         2          Heap Sort         1.336294e-05
# 32   reversed       10         3          Heap Sort         1.277618e-05
# 33   reversed       10         4          Heap Sort         1.281025e-05
# 34   reversed       10         5          Heap Sort         1.361921e-05
# 35   reversed       100        1          Heap Sort         2.467546e-04
# 36   reversed       100        2          Heap Sort         2.562218e-04
# 37   reversed       100        3          Heap Sort         2.467044e-04
# 38   reversed       100        4          Heap Sort         2.468025e-04
# 39   reversed       100        5          Heap Sort         2.558359e-04
# 40   reversed       1000       1          Heap Sort         4.026154e-03
# 41   reversed       1000       2          Heap Sort         3.959128e-03
# 42   reversed       1000       3          Heap Sort         3.934818e-03
# 43   reversed       1000       4          Heap Sort         3.941188e-03
# 44   reversed       1000       5          Heap Sort         4.040688e-03
# 45   reversed       10000      1          Heap Sort         5.668924e-02
# 46   reversed       10000      2          Heap Sort         5.693414e-02
# 47   reversed       10000      3          Heap Sort         5.694302e-02
# 48   reversed       10000      4          Heap Sort         5.691746e-02
# 49   reversed       10000      5          Heap Sort         5.694062e-02
# 50   reversed       100000     1          Heap Sort         1.018156e+00
# 51   reversed       100000     2          Heap Sort         9.746102e-01
# 52   reversed       100000     3          Heap Sort         9.749295e-01
# 53   reversed       100000     4          Heap Sort         9.970369e-01
# 54   reversed       100000     5          Heap Sort         9.897069e-01
# 55   reversed       1000000    1          Heap Sort         1.141129e+01
# 56   reversed       1000000    2          Heap Sort         1.183892e+01
# 57   reversed       1000000    3          Heap Sort         1.003985e+01
# 58   reversed       1000000    4          Heap Sort         9.524816e+00
# 59   reversed       1000000    5          Heap Sort         9.484131e+00
# 60   random         10         1          Heap Sort         4.255846e-05
# 61   random         10         2          Heap Sort         4.363419e-05
# 62   random         10         3          Heap Sort         4.244008e-05
# 63   random         10         4          Heap Sort         4.309129e-05
# 64   random         10         5          Heap Sort         4.241885e-05
# 65   random         100        1          Heap Sort         7.138750e-04
# 66   random         100        2          Heap Sort         7.186868e-04
# 67   random         100        3          Heap Sort         7.177172e-04
# 68   random         100        4          Heap Sort         7.179588e-04
# 69   random         100        5          Heap Sort         7.233658e-04
# 70   random         1000       1          Heap Sort         1.169041e-02
# 71   random         1000       2          Heap Sort         1.148474e-02
# 72   random         1000       3          Heap Sort         1.156228e-02
# 73   random         1000       4          Heap Sort         1.156084e-02
# 74   random         1000       5          Heap Sort         1.131912e-02
# 75   random         10000      1          Heap Sort         1.623184e-01
# 76   random         10000      2          Heap Sort         1.581266e-01
# 77   random         10000      3          Heap Sort         1.581535e-01
# 78   random         10000      4          Heap Sort         1.581109e-01
# 79   random         10000      5          Heap Sort         1.606127e-01
# 80   random         100000     1          Heap Sort         2.009663e+00
# 81   random         100000     2          Heap Sort         2.008334e+00
# 82   random         100000     3          Heap Sort         2.137779e+00
# 83   random         100000     4          Heap Sort         1.998335e+00
# 84   random         100000     5          Heap Sort         2.004607e+00
# 85   random         1000000    1          Heap Sort         2.480330e+01
# 86   random         1000000    2          Heap Sort         2.619809e+01
# 87   random         1000000    3          Heap Sort         2.450947e+01
# 88   random         1000000    4          Heap Sort         2.460547e+01
# 89   random         1000000    5          Heap Sort         2.458020e+01
# 90   identical      10         1          Heap Sort         1.244908e-06
# 91   identical      10         2          Heap Sort         1.189707e-06
# 92   identical      10         3          Heap Sort         1.155353e-06
# 93   identical      10         4          Heap Sort         1.194396e-06
# 94   identical      10         5          Heap Sort         1.154101e-06
# 95   identical      100        1          Heap Sort         1.203734e-06
# ..         ...      ...       ..                ...                  ...
# 84   random         100000     5          Python Sort       4.997654e-02
# 85   random         1000000    1          Python Sort       8.233355e-01
# 86   random         1000000    2          Python Sort       7.636899e-01
# 87   random         1000000    3          Python Sort       7.729756e-01
# 88   random         1000000    4          Python Sort       7.989999e-01
# 89   random         1000000    5          Python Sort       8.264675e-01
# 90   identical      10         1          Python Sort       3.957030e-07
# 91   identical      10         2          Python Sort       4.081652e-07
# 92   identical      10         3          Python Sort       3.955860e-07
# 93   identical      10         4          Python Sort       4.224788e-07
# 94   identical      10         5          Python Sort       4.104002e-07
# 95   identical      100        1          Python Sort       3.953978e-07
# 96   identical      100        2          Python Sort       3.954114e-07
# 97   identical      100        3          Python Sort       3.956278e-07
# 98   identical      100        4          Python Sort       3.954092e-07
# 99   identical      100        5          Python Sort       3.954664e-07
# 100  identical      1000       1          Python Sort       4.128062e-07
# 101  identical      1000       2          Python Sort       3.954084e-07
# 102  identical      1000       3          Python Sort       4.115204e-07
# 103  identical      1000       4          Python Sort       3.952714e-07
# 104  identical      1000       5          Python Sort       3.957686e-07
# 105  identical      10000      1          Python Sort       4.088120e-07
# 106  identical      10000      2          Python Sort       3.957878e-07
# 107  identical      10000      3          Python Sort       4.729060e-07
# 108  identical      10000      4          Python Sort       4.209416e-07
# 109  identical      10000      5          Python Sort       5.415132e-07
# 110  identical      100000     1          Python Sort       3.954186e-07
# 111  identical      100000     2          Python Sort       3.955832e-07
# 112  identical      100000     3          Python Sort       3.958622e-07
# 113  identical      100000     4          Python Sort       4.082994e-07
# 114  identical      100000     5          Python Sort       3.954736e-07
# 115  identical      1000000    1          Python Sort       4.087214e-07
# 116  identical      1000000    2          Python Sort       3.951698e-07
# 117  identical      1000000    3          Python Sort       3.951132e-07
# 118  identical      1000000    4          Python Sort       3.950724e-07
# 119  identical      1000000    5          Python Sort       4.257486e-07
# 0    sorted         10         1          Quicksort         1.545636e-05
# 1    sorted         10         2          Quicksort         1.391525e-05
# 2    sorted         10         3          Quicksort         1.421673e-05
# 3    sorted         10         4          Quicksort         1.372158e-05
# 4    sorted         10         5          Quicksort         1.417066e-05
# 5    sorted         100        1          Quicksort         7.753490e-04
# 6    sorted         100        2          Quicksort         8.340150e-04
# 7    sorted         100        3          Quicksort         7.530912e-04
# 8    sorted         100        4          Quicksort         7.553540e-04
# 9    sorted         100        5          Quicksort         7.775670e-04
# 10   sorted         1000       1          Quicksort         7.598796e-02
# 11   sorted         1000       2          Quicksort         7.595706e-02
# 12   sorted         1000       3          Quicksort         7.795098e-02
# 13   sorted         1000       4          Quicksort         7.855380e-02
# 14   sorted         1000       5          Quicksort         8.186438e-02
# 15   reversed       10         1          Quicksort         1.247101e-05
# 16   reversed       10         2          Quicksort         1.206373e-05
# 17   reversed       10         3          Quicksort         1.156121e-05
# 18   reversed       10         4          Quicksort         1.156041e-05
# 19   reversed       10         5          Quicksort         1.198044e-05
# 20   reversed       100        1          Quicksort         5.245558e-04
# 21   reversed       100        2          Quicksort         5.615812e-04
# 22   reversed       100        3          Quicksort         5.325078e-04
# 23   reversed       100        4          Quicksort         5.618116e-04
# 24   reversed       100        5          Quicksort         5.246006e-04
# 25   reversed       1000       1          Quicksort         5.357000e-02
# 26   reversed       1000       2          Quicksort         5.527142e-02
# 27   reversed       1000       3          Quicksort         5.359522e-02
# 28   reversed       1000       4          Quicksort         5.386442e-02
# 29   reversed       1000       5          Quicksort         5.374098e-02
# 30   random         10         1          Quicksort         1.848179e-05
# 31   random         10         2          Quicksort         1.830173e-05
# 32   random         10         3          Quicksort         1.831985e-05
# 33   random         10         4          Quicksort         1.836969e-05
# 34   random         10         5          Quicksort         1.832092e-05
# 35   random         100        1          Quicksort         3.285241e-04
# 36   random         100        2          Quicksort         3.341183e-04
# 37   random         100        3          Quicksort         3.278497e-04
# 38   random         100        4          Quicksort         3.278568e-04
# 39   random         100        5          Quicksort         3.290056e-04
# 40   random         1000       1          Quicksort         6.222812e-03
# 41   random         1000       2          Quicksort         6.129158e-03
# 42   random         1000       3          Quicksort         6.146878e-03
# 43   random         1000       4          Quicksort         6.222792e-03
# 44   random         1000       5          Quicksort         6.136034e-03
# 45   identical      10         1          Quicksort         5.023594e-07
# 46   identical      10         2          Quicksort         4.866982e-07
# 47   identical      10         3          Quicksort         4.865700e-07
# 48   identical      10         4          Quicksort         4.874000e-07
# 49   identical      10         5          Quicksort         4.930370e-07
# 50   identical      100        1          Quicksort         4.942510e-07
# 51   identical      100        2          Quicksort         4.886210e-07
# 52   identical      100        3          Quicksort         4.886140e-07
# 53   identical      100        4          Quicksort         4.896510e-07
# 54   identical      100        5          Quicksort         5.033850e-07
# 55   identical      1000       1          Quicksort         4.870736e-07
# 56   identical      1000       2          Quicksort         4.870066e-07
# 57   identical      1000       3          Quicksort         4.873784e-07
# 58   identical      1000       4          Quicksort         4.871272e-07
# 59   identical      1000       5          Quicksort         5.025602e-07
#
# [444 rows x 5 columns]

# %% [markdown]
# # Plot for Sorted Data

# %%
df_sorted = combined[combined['input ordering'] == 'sorted']

# %%
df_sorted
# Out:
#    input ordering input size run number sorting algorithm          time
# 0   sorted         10         1          Heap Sort         1.771354e-05
# 1   sorted         10         2          Heap Sort         2.327142e-05
# 2   sorted         10         3          Heap Sort         2.134281e-05
# 3   sorted         10         4          Heap Sort         2.038003e-05
# 4   sorted         10         5          Heap Sort         1.681160e-05
# 5   sorted         100        1          Heap Sort         3.005371e-04
# 6   sorted         100        2          Heap Sort         2.929288e-04
# 7   sorted         100        3          Heap Sort         2.932095e-04
# 8   sorted         100        4          Heap Sort         2.978879e-04
# 9   sorted         100        5          Heap Sort         2.936115e-04
# 10  sorted         1000       1          Heap Sort         4.776066e-03
# 11  sorted         1000       2          Heap Sort         4.779546e-03
# 12  sorted         1000       3          Heap Sort         4.937474e-03
# 13  sorted         1000       4          Heap Sort         4.768794e-03
# 14  sorted         1000       5          Heap Sort         4.565190e-03
# 15  sorted         10000      1          Heap Sort         6.549416e-02
# 16  sorted         10000      2          Heap Sort         6.321482e-02
# 17  sorted         10000      3          Heap Sort         6.484914e-02
# 18  sorted         10000      4          Heap Sort         6.289262e-02
# 19  sorted         10000      5          Heap Sort         6.305608e-02
# 20  sorted         100000     1          Heap Sort         1.074641e+00
# 21  sorted         100000     2          Heap Sort         8.157131e-01
# 22  sorted         100000     3          Heap Sort         8.243548e-01
# 23  sorted         100000     4          Heap Sort         8.165248e-01
# 24  sorted         100000     5          Heap Sort         8.069561e-01
# 25  sorted         1000000    1          Heap Sort         1.012387e+01
# 26  sorted         1000000    2          Heap Sort         1.001244e+01
# 27  sorted         1000000    3          Heap Sort         1.002861e+01
# 28  sorted         1000000    4          Heap Sort         1.001769e+01
# 29  sorted         1000000    5          Heap Sort         1.000025e+01
# 0   sorted         10         1          Merge Sort        1.627836e-05
# 1   sorted         10         2          Merge Sort        2.110944e-05
# 2   sorted         10         3          Merge Sort        2.036687e-05
# 3   sorted         10         4          Merge Sort        2.026609e-05
# 4   sorted         10         5          Merge Sort        2.018794e-05
# 5   sorted         100        1          Merge Sort        2.218562e-04
# 6   sorted         100        2          Merge Sort        2.217573e-04
# 7   sorted         100        3          Merge Sort        2.217860e-04
# 8   sorted         100        4          Merge Sort        2.300631e-04
# 9   sorted         100        5          Merge Sort        2.220095e-04
# 10  sorted         1000       1          Merge Sort        2.944327e-03
# 11  sorted         1000       2          Merge Sort        2.928238e-03
# 12  sorted         1000       3          Merge Sort        2.926932e-03
# 13  sorted         1000       4          Merge Sort        3.049811e-03
# 14  sorted         1000       5          Merge Sort        2.990346e-03
# 15  sorted         10000      1          Merge Sort        3.848766e-02
# 16  sorted         10000      2          Merge Sort        3.918030e-02
# 17  sorted         10000      3          Merge Sort        3.847136e-02
# 18  sorted         10000      4          Merge Sort        3.891435e-02
# 19  sorted         10000      5          Merge Sort        3.886840e-02
# 20  sorted         100000     1          Merge Sort        4.808213e-01
# 21  sorted         100000     2          Merge Sort        4.758670e-01
# 22  sorted         100000     3          Merge Sort        4.920925e-01
# 23  sorted         100000     4          Merge Sort        4.990586e-01
# 24  sorted         100000     5          Merge Sort        4.935466e-01
# 25  sorted         1000000    1          Merge Sort        6.785499e+00
# 26  sorted         1000000    2          Merge Sort        6.572416e+00
# 27  sorted         1000000    3          Merge Sort        6.312896e+00
# 28  sorted         1000000    4          Merge Sort        6.330814e+00
# 29  sorted         1000000    5          Merge Sort        6.273962e+00
# 0   sorted         10         NaN        NumPy-sort        4.121696e-06
# 1   sorted         100        NaN        NumPy-sort        1.048106e-05
# 2   sorted         1000       NaN        NumPy-sort        7.044676e-05
# 3   sorted         10000      NaN        NumPy-sort        6.955560e-04
# 4   sorted         100000     NaN        NumPy-sort        8.920972e-03
# 5   sorted         1000000    NaN        NumPy-sort        2.498635e-01
# 0   sorted         10         1          Python Sort       6.883962e-07
# 1   sorted         10         2          Python Sort       7.315646e-07
# 2   sorted         10         3          Python Sort       6.919138e-07
# 3   sorted         10         4          Python Sort       6.912934e-07
# 4   sorted         10         5          Python Sort       6.823590e-07
# 5   sorted         100        1          Python Sort       2.936621e-06
# 6   sorted         100        2          Python Sort       2.984569e-06
# 7   sorted         100        3          Python Sort       2.904369e-06
# 8   sorted         100        4          Python Sort       2.913735e-06
# 9   sorted         100        5          Python Sort       2.905791e-06
# 10  sorted         1000       1          Python Sort       2.378813e-05
# 11  sorted         1000       2          Python Sort       2.380413e-05
# 12  sorted         1000       3          Python Sort       2.384280e-05
# 13  sorted         1000       4          Python Sort       2.379801e-05
# 14  sorted         1000       5          Python Sort       2.377820e-05
# 15  sorted         10000      1          Python Sort       2.534280e-04
# 16  sorted         10000      2          Python Sort       2.536862e-04
# 17  sorted         10000      3          Python Sort       2.532081e-04
# 18  sorted         10000      4          Python Sort       2.529179e-04
# 19  sorted         10000      5          Python Sort       2.530189e-04
# 20  sorted         100000     1          Python Sort       3.130540e-03
# 21  sorted         100000     2          Python Sort       3.082691e-03
# 22  sorted         100000     3          Python Sort       3.117670e-03
# 23  sorted         100000     4          Python Sort       3.093391e-03
# 24  sorted         100000     5          Python Sort       3.137036e-03
# 25  sorted         1000000    1          Python Sort       1.325038e-01
# 26  sorted         1000000    2          Python Sort       1.288782e-01
# 27  sorted         1000000    3          Python Sort       1.287989e-01
# 28  sorted         1000000    4          Python Sort       1.372342e-01
# 29  sorted         1000000    5          Python Sort       1.288038e-01
# 0   sorted         10         1          Quicksort         1.545636e-05
# 1   sorted         10         2          Quicksort         1.391525e-05
# 2   sorted         10         3          Quicksort         1.421673e-05
# 3   sorted         10         4          Quicksort         1.372158e-05
# 4   sorted         10         5          Quicksort         1.417066e-05
# 5   sorted         100        1          Quicksort         7.753490e-04
# 6   sorted         100        2          Quicksort         8.340150e-04
# 7   sorted         100        3          Quicksort         7.530912e-04
# 8   sorted         100        4          Quicksort         7.553540e-04
# 9   sorted         100        5          Quicksort         7.775670e-04
# 10  sorted         1000       1          Quicksort         7.598796e-02
# 11  sorted         1000       2          Quicksort         7.595706e-02
# 12  sorted         1000       3          Quicksort         7.795098e-02
# 13  sorted         1000       4          Quicksort         7.855380e-02
# 14  sorted         1000       5          Quicksort         8.186438e-02

# %%
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_sorted)

# %% [markdown]
# ## Plot for reversed data

# %%
df_reversed = combined[combined['input ordering'] == 'reversed']
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_reversed)

# %% [markdown]
# ## Plot for random data

# %%
df_random = combined[combined['input ordering'] == 'random']
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_random)

# %% [markdown]
# ## Plot for Identical data

# %%
df_identical = combined[combined['input ordering'] == 'identical']
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_identical)
