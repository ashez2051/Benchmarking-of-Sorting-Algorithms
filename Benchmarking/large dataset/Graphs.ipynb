# %% [markdown]
# ## For large dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#plt.figure(figsize=(84/25.4, 55/25.4))

# %%
sns.set(rc={'figure.figsize':(84/25.4,55/25.4)})
sns.set_style("whitegrid")

# %%
sns.set(style='whitegrid', rc={"grid.linewidth": 0.1})
sns.set_context("paper", font_scale=0.9) 
color = sns.color_palette("Set2", 6)

# %%
quick =pd.read_pickle("./benchmark_results_quick.pkl")

# %%
fig1 = sns.lineplot(x="input size", y="time", data=quick, hue ='input ordering')
plt.title('Quick Sort')
fig1 = fig1.get_figure()
fig1.savefig("output1.pdf")

# %%
heap=pd.read_pickle("./benchmark_results_heap.pkl")

# %%
fig1 = sns.lineplot(x="input size", y="time", data=heap, hue ='input ordering')
plt.title('Heap Sort')
fig1 = fig1.get_figure()
fig1.savefig("output2.pdf")

# %%
merge=pd.read_pickle("./benchmark_results_merge.pkl")

# %%
fig1 = sns.lineplot(x="input size", y="time", data=merge, hue ='input ordering')
plt.title('Merge Sort')
fig1 = fig1.get_figure()
fig1.savefig("output3.pdf")

# %%
python = pd.read_pickle("./benchmark_results_python.pkl")

# %%
python
# Out:
#     input ordering input size run number sorting algorithm          time
# 0           sorted         10          1       Python Sort  7.735940e-07
# 1           sorted         10          2       Python Sort  7.129910e-07
# 2           sorted         10          3       Python Sort  6.806204e-07
# 3           sorted         10          4       Python Sort  6.813988e-07
# 4           sorted         10          5       Python Sort  6.839950e-07
# 5           sorted        100          1       Python Sort  3.178622e-06
# 6           sorted        100          2       Python Sort  3.327099e-06
# 7           sorted        100          3       Python Sort  2.977926e-06
# 8           sorted        100          4       Python Sort  2.961996e-06
# 9           sorted        100          5       Python Sort  2.971586e-06
# 10          sorted       1000          1       Python Sort  2.420202e-05
# 11          sorted       1000          2       Python Sort  2.391072e-05
# 12          sorted       1000          3       Python Sort  2.380030e-05
# 13          sorted       1000          4       Python Sort  2.378826e-05
# 14          sorted       1000          5       Python Sort  2.382905e-05
# 15          sorted      10000          1       Python Sort  2.540224e-04
# 16          sorted      10000          2       Python Sort  2.534946e-04
# 17          sorted      10000          3       Python Sort  2.543476e-04
# 18          sorted      10000          4       Python Sort  2.542537e-04
# 19          sorted      10000          5       Python Sort  2.542285e-04
# 20          sorted     100000          1       Python Sort  3.006595e-03
# 21          sorted     100000          2       Python Sort  2.968938e-03
# 22          sorted     100000          3       Python Sort  2.933220e-03
# 23          sorted     100000          4       Python Sort  2.937951e-03
# 24          sorted     100000          5       Python Sort  2.947936e-03
# 25          sorted    1000000          1       Python Sort  1.278749e-01
# 26          sorted    1000000          2       Python Sort  1.285035e-01
# 27          sorted    1000000          3       Python Sort  1.292338e-01
# 28          sorted    1000000          4       Python Sort  1.284992e-01
# 29          sorted    1000000          5       Python Sort  1.269479e-01
# ..             ...        ...        ...               ...           ...
# 90       identical         10          1       Python Sort  6.581660e-07
# 91       identical         10          2       Python Sort  5.041240e-07
# 92       identical         10          3       Python Sort  4.728304e-07
# 93       identical         10          4       Python Sort  4.985266e-07
# 94       identical         10          5       Python Sort  4.654768e-07
# 95       identical        100          1       Python Sort  3.979861e-07
# 96       identical        100          2       Python Sort  4.304054e-07
# 97       identical        100          3       Python Sort  4.753979e-07
# 98       identical        100          4       Python Sort  4.010830e-07
# 99       identical        100          5       Python Sort  4.201118e-07
# 100      identical       1000          1       Python Sort  6.640174e-07
# 101      identical       1000          2       Python Sort  4.502054e-07
# 102      identical       1000          3       Python Sort  3.958820e-07
# 103      identical       1000          4       Python Sort  3.950574e-07
# 104      identical       1000          5       Python Sort  3.947776e-07
# 105      identical      10000          1       Python Sort  6.519532e-07
# 106      identical      10000          2       Python Sort  6.520322e-07
# 107      identical      10000          3       Python Sort  6.608356e-07
# 108      identical      10000          4       Python Sort  5.474054e-07
# 109      identical      10000          5       Python Sort  4.876702e-07
# 110      identical     100000          1       Python Sort  3.949188e-07
# 111      identical     100000          2       Python Sort  4.075244e-07
# 112      identical     100000          3       Python Sort  4.266716e-07
# 113      identical     100000          4       Python Sort  4.071100e-07
# 114      identical     100000          5       Python Sort  3.942230e-07
# 115      identical    1000000          1       Python Sort  3.952042e-07
# 116      identical    1000000          2       Python Sort  4.138938e-07
# 117      identical    1000000          3       Python Sort  4.077045e-07
# 118      identical    1000000          4       Python Sort  4.182859e-07
# 119      identical    1000000          5       Python Sort  4.094371e-07
#
# [120 rows x 5 columns]

# %%
fig1 = sns.lineplot(x="input size", y="time", data=python, hue ='input ordering')
plt.title('Python Sort')
fig1 = fig1.get_figure()
fig1.savefig("output4.pdf")

# %%
numpy = pd.read_pickle("./benchmark_results_numpy.pkl")

# %%
fig1 = sns.lineplot(x="input size", y="time", data=numpy, hue ='input ordering')
plt.title('Numpy Sort')
fig1 = fig1.get_figure()
fig1.savefig("output5.pdf")

# %% [markdown]
# ## Combined Dataframe

# %%
frames = [ heap, merge,quick,numpy,python]

# %%
combined = pd.concat(frames, axis =0)
# Out:
# C:\Users\Ashesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Plot for sorted data

# %%
df_sorted = combined[combined['input ordering'] == 'sorted']

# %%
fig1 = sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_sorted)
plt.title('Sorted Data')
fig1 = fig1.get_figure()
fig1.savefig("output6.pdf")

# %% [markdown]
# ## Plot for reversed data

# %%
df_reversed = combined[combined['input ordering'] == 'reversed']
fig1= sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_reversed)
plt.title('Reversed Data')
fig1 = fig1.get_figure()
fig1.savefig("output7.pdf")

# %% [markdown]
# ## Random Data

# %%
df_random = combined[combined['input ordering'] == 'random']
fig1=sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_random)
plt.title("Random Data")
fig1 = fig1.get_figure()
fig1.savefig("output8.pdf")

# %% [markdown]
# ## Identical Data

# %%
df_identical = combined[combined['input ordering'] == 'identical']
fig1=sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_identical)
plt.title("Identical Data")
fig1 = fig1.get_figure()
fig1.savefig("output9.pdf")
