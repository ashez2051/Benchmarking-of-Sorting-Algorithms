# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import timeit
import copy

# %%
pd.set_option('display.max_columns',192)
pd.set_option('display.max_rows',192)
pd.set_option('display.max_colwidth',-1)
plt.rcParams['figure.figsize']=(15,9)

# %%
import sys
print("System version:", sys.version)
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# System version: 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]
# Pandas version: 0.24.2
# NumPy version: 1.16.4

# %% [markdown]
# ## Quick Sort

# %%
def quicksort(A):
    _quicksort1(A, 0, len(A) - 1)
    return A

def partition(A, p, r):
    x = A[r]
    i = p - 1
    for j in range(p, r):
        if A[j] <= x:
            i += 1
            A[i], A[j] = A[j], A[i]
    A[i + 1], A[r] =  A[r], A[i + 1]
    return i + 1

def _quicksort1(A, p, r):
    if p < r:
        q = partition(A, p, r)
        _quicksort1(A, p, q - 1)
        _quicksort1(A, q + 1, r)

# %% [markdown]
# ## Benchmarking

# %%
np.random.seed(12345)
benchmark_results_quick = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': quicksort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Quick sort minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
        
        
        for run_number in range(5):
            benchmark_results_quick = benchmark_results_quick.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Quicksort',
                                                          'time':t[run_number]/n_ar},
                                                             ignore_index=True)
# Out:
# Quick sort minimum time on sorted data of size 10^1: 1.3705315000000007e-05
# Quick sort minimum time on sorted data of size 10^2: 0.0007818108000000006
# Quick sort minimum time on sorted data of size 10^3: 0.07646474000000011
# Quick sort minimum time on reversed data of size 10^1: 1.1611689999999975e-05
# Quick sort minimum time on reversed data of size 10^2: 0.0005266286000000022
# Quick sort minimum time on reversed data of size 10^3: 0.05364837999999992
# Quick sort minimum time on random data of size 10^1: 1.7943880000000157e-05
# Quick sort minimum time on random data of size 10^2: 0.00033309249999999936
# Quick sort minimum time on random data of size 10^3: 0.0060454759999999655
# Quick sort minimum time on identical data of size 10^1: 4.901026000000002e-07
# Quick sort minimum time on identical data of size 10^2: 4.966026000000028e-07
# Quick sort minimum time on identical data of size 10^3: 4.966494000000025e-07

# %%
benchmark_results_quick.to_pickle("./benchmark_results_quick.pkl")

# %%
pd.read_pickle("./benchmark_results_quick.pkl")
# Out:
#    input ordering input size run number sorting algorithm          time
# 0   sorted         10         1          Quicksort         1.370532e-05
# 1   sorted         10         2          Quicksort         1.424158e-05
# 2   sorted         10         3          Quicksort         1.488926e-05
# 3   sorted         10         4          Quicksort         1.436828e-05
# 4   sorted         10         5          Quicksort         1.416030e-05
# 5   sorted         100        1          Quicksort         7.818108e-04
# 6   sorted         100        2          Quicksort         8.147652e-04
# 7   sorted         100        3          Quicksort         1.002275e-03
# 8   sorted         100        4          Quicksort         9.131868e-04
# 9   sorted         100        5          Quicksort         7.874422e-04
# 10  sorted         1000       1          Quicksort         7.649096e-02
# 11  sorted         1000       2          Quicksort         7.802188e-02
# 12  sorted         1000       3          Quicksort         7.646474e-02
# 13  sorted         1000       4          Quicksort         8.938344e-02
# 14  sorted         1000       5          Quicksort         7.698892e-02
# 15  reversed       10         1          Quicksort         1.515305e-05
# 16  reversed       10         2          Quicksort         1.162079e-05
# 17  reversed       10         3          Quicksort         1.167176e-05
# 18  reversed       10         4          Quicksort         1.161243e-05
# 19  reversed       10         5          Quicksort         1.161169e-05
# 20  reversed       100        1          Quicksort         5.315372e-04
# 21  reversed       100        2          Quicksort         5.295034e-04
# 22  reversed       100        3          Quicksort         5.266286e-04
# 23  reversed       100        4          Quicksort         5.295096e-04
# 24  reversed       100        5          Quicksort         5.634404e-04
# 25  reversed       1000       1          Quicksort         5.387218e-02
# 26  reversed       1000       2          Quicksort         5.486160e-02
# 27  reversed       1000       3          Quicksort         5.367374e-02
# 28  reversed       1000       4          Quicksort         5.364838e-02
# 29  reversed       1000       5          Quicksort         5.565638e-02
# 30  random         10         1          Quicksort         1.794388e-05
# 31  random         10         2          Quicksort         1.796615e-05
# 32  random         10         3          Quicksort         1.807203e-05
# 33  random         10         4          Quicksort         1.803088e-05
# 34  random         10         5          Quicksort         1.798376e-05
# 35  random         100        1          Quicksort         3.400958e-04
# 36  random         100        2          Quicksort         3.330925e-04
# 37  random         100        3          Quicksort         3.346741e-04
# 38  random         100        4          Quicksort         3.372046e-04
# 39  random         100        5          Quicksort         3.369067e-04
# 40  random         1000       1          Quicksort         6.045476e-03
# 41  random         1000       2          Quicksort         6.054046e-03
# 42  random         1000       3          Quicksort         6.046606e-03
# 43  random         1000       4          Quicksort         6.125266e-03
# 44  random         1000       5          Quicksort         6.050340e-03
# 45  identical      10         1          Quicksort         4.938246e-07
# 46  identical      10         2          Quicksort         4.901026e-07
# 47  identical      10         3          Quicksort         4.968084e-07
# 48  identical      10         4          Quicksort         5.358980e-07
# 49  identical      10         5          Quicksort         4.918264e-07
# 50  identical      100        1          Quicksort         4.966026e-07
# 51  identical      100        2          Quicksort         5.076208e-07
# 52  identical      100        3          Quicksort         5.101448e-07
# 53  identical      100        4          Quicksort         5.044602e-07
# 54  identical      100        5          Quicksort         5.028214e-07
# 55  identical      1000       1          Quicksort         5.125258e-07
# 56  identical      1000       2          Quicksort         4.966494e-07
# 57  identical      1000       3          Quicksort         5.179202e-07
# 58  identical      1000       4          Quicksort         5.550268e-07
# 59  identical      1000       5          Quicksort         6.193958e-07

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_quick, hue ='input ordering')

# %% [markdown]
# ## Heap Sort

# %%
# Python program for implementation of heap Sort 
  
# To heapify subtree rooted at index i. 
# n is size of heap 
def heapify(arr, n, i): 
    largest = i  # Initialize largest as root 
    l = 2 * i + 1     # left = 2*i + 1 
    r = 2 * i + 2     # right = 2*i + 2 
  
    # See if left child of root exists and is 
    # greater than root 
    if l < n and arr[i] < arr[l]: 
        largest = l 
  
    # See if right child of root exists and is 
    # greater than root 
    if r < n and arr[largest] < arr[r]: 
        largest = r 
  
    # Change root, if needed 
    if largest != i: 
        arr[i],arr[largest] = arr[largest],arr[i]  # swap 
  
        # Heapify the root. 
        heapify(arr, n, largest) 
        
## main function to sort given array       
def sort_heap(arr): 
    n = len(arr) 
  
    # Build a maxheap. 
    for i in range(n, -1, -1): 
        heapify(arr, n, i) 
  
    # One by one extract elements 
    for i in range(n-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i]   # swap 
        heapify(arr, i, 0) 
        
    return arr

# %% [markdown]
#  ## Benchmarking

# %%
np.random.seed(12345)
benchmark_results_heap = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': sort_heap,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Heap sort minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
       
        for run_number in range(5):
            benchmark_results_heap = benchmark_results_heap.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Heap Sort',
                                                          'time':t[run_number]/n_ar},
                                                        ignore_index=True)
# Out:
# Heap sort minimum time on sorted data of size 10^1: 1.632322500000001e-05
# Heap sort minimum time on sorted data of size 10^2: 0.0002944232999999983
# Heap sort minimum time on sorted data of size 10^3: 0.004628857999999951
# Heap sort minimum time on reversed data of size 10^1: 1.2827705000000123e-05
# Heap sort minimum time on reversed data of size 10^2: 0.00024586919999999423
# Heap sort minimum time on reversed data of size 10^3: 0.00398964399999997
# Heap sort minimum time on random data of size 10^1: 3.532434000000038e-05
# Heap sort minimum time on random data of size 10^2: 0.0007168350000000032
# Heap sort minimum time on random data of size 10^3: 0.011258399999999825
# Heap sort minimum time on identical data of size 10^1: 1.1243534999999838e-06
# Heap sort minimum time on identical data of size 10^2: 1.1258244999999788e-06
# Heap sort minimum time on identical data of size 10^3: 1.124318500000001e-06

# %%
benchmark_results_heap.to_pickle("./benchmark_results_heap.pkl")

# %%
pd.read_pickle("./benchmark_results_heap.pkl")
# Out:
#    input ordering input size run number sorting algorithm      time
# 0   sorted         10         1          Heap Sort         0.000018
# 1   sorted         10         2          Heap Sort         0.000016
# 2   sorted         10         3          Heap Sort         0.000016
# 3   sorted         10         4          Heap Sort         0.000018
# 4   sorted         10         5          Heap Sort         0.000017
# 5   sorted         100        1          Heap Sort         0.000304
# 6   sorted         100        2          Heap Sort         0.000305
# 7   sorted         100        3          Heap Sort         0.000296
# 8   sorted         100        4          Heap Sort         0.000294
# 9   sorted         100        5          Heap Sort         0.000308
# 10  sorted         1000       1          Heap Sort         0.004655
# 11  sorted         1000       2          Heap Sort         0.004629
# 12  sorted         1000       3          Heap Sort         0.004676
# 13  sorted         1000       4          Heap Sort         0.004788
# 14  sorted         1000       5          Heap Sort         0.004988
# 15  reversed       10         1          Heap Sort         0.000013
# 16  reversed       10         2          Heap Sort         0.000013
# 17  reversed       10         3          Heap Sort         0.000013
# 18  reversed       10         4          Heap Sort         0.000013
# 19  reversed       10         5          Heap Sort         0.000014
# 20  reversed       100        1          Heap Sort         0.000257
# 21  reversed       100        2          Heap Sort         0.000246
# 22  reversed       100        3          Heap Sort         0.000266
# 23  reversed       100        4          Heap Sort         0.000247
# 24  reversed       100        5          Heap Sort         0.000247
# 25  reversed       1000       1          Heap Sort         0.003991
# 26  reversed       1000       2          Heap Sort         0.004015
# 27  reversed       1000       3          Heap Sort         0.003990
# 28  reversed       1000       4          Heap Sort         0.003997
# 29  reversed       1000       5          Heap Sort         0.004177
# 30  random         10         1          Heap Sort         0.000035
# 31  random         10         2          Heap Sort         0.000036
# 32  random         10         3          Heap Sort         0.000035
# 33  random         10         4          Heap Sort         0.000035
# 34  random         10         5          Heap Sort         0.000036
# 35  random         100        1          Heap Sort         0.000736
# 36  random         100        2          Heap Sort         0.000717
# 37  random         100        3          Heap Sort         0.000718
# 38  random         100        4          Heap Sort         0.000719
# 39  random         100        5          Heap Sort         0.000717
# 40  random         1000       1          Heap Sort         0.011510
# 41  random         1000       2          Heap Sort         0.011268
# 42  random         1000       3          Heap Sort         0.011356
# 43  random         1000       4          Heap Sort         0.011572
# 44  random         1000       5          Heap Sort         0.011258
# 45  identical      10         1          Heap Sort         0.000001
# 46  identical      10         2          Heap Sort         0.000001
# 47  identical      10         3          Heap Sort         0.000001
# 48  identical      10         4          Heap Sort         0.000001
# 49  identical      10         5          Heap Sort         0.000001
# 50  identical      100        1          Heap Sort         0.000001
# 51  identical      100        2          Heap Sort         0.000001
# 52  identical      100        3          Heap Sort         0.000001
# 53  identical      100        4          Heap Sort         0.000001
# 54  identical      100        5          Heap Sort         0.000001
# 55  identical      1000       1          Heap Sort         0.000001
# 56  identical      1000       2          Heap Sort         0.000001
# 57  identical      1000       3          Heap Sort         0.000001
# 58  identical      1000       4          Heap Sort         0.000001
# 59  identical      1000       5          Heap Sort         0.000001

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_heap, hue ='input ordering')

# %% [markdown]
# ## Merge Sort

# %%
def merge_sort(data):
   
    if len(data) > 1:
        
        mid = int(len(data)/2)
        lefthalf = data[:mid]
        righthalf = data[mid:]
        
        merge_sort(lefthalf)
        merge_sort(righthalf)
        
        i=0
        j=0
        k=0
        
        while i<len(lefthalf) and j<len(righthalf):
            
            if lefthalf[i]<righthalf[j]:
                data[k] = lefthalf[i]
                
                i+=1
                
            else:
                data[k]= righthalf[j]
                j+=1
                
            k+=1
            
        while i<len(lefthalf):
            data[k] = lefthalf[i]
            i+=1
            k+=1
            
        while j<len(righthalf):
            data[k] = righthalf[j]
            j= j+1
            k= k+1
            
        return data

# %%
np.random.seed(12345)
benchmark_results_merge = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': merge_sort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Merge Sort minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
        
        
        for run_number in range(5):
            benchmark_results_merge = benchmark_results_merge.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Merge Sort',
                                                          'time':t[run_number]/n_ar},
                                                        ignore_index=True)
# Out:
# Merge Sort minimum time on sorted data of size 10^1: 1.553653999999973e-05
# Merge Sort minimum time on sorted data of size 10^2: 0.00022272470000000055
# Merge Sort minimum time on sorted data of size 10^3: 0.0029484839999999934
# Merge Sort minimum time on reversed data of size 10^1: 1.6470500000000143e-05
# Merge Sort minimum time on reversed data of size 10^2: 0.00023226660000000266
# Merge Sort minimum time on reversed data of size 10^3: 0.002998436999999967
# Merge Sort minimum time on random data of size 10^1: 2.9160029999999892e-05
# Merge Sort minimum time on random data of size 10^2: 0.00047492239999999696
# Merge Sort minimum time on random data of size 10^3: 0.006620929999999987
# Merge Sort minimum time on identical data of size 10^1: 4.0287619999998015e-07
# Merge Sort minimum time on identical data of size 10^2: 4.038487999999916e-07
# Merge Sort minimum time on identical data of size 10^3: 4.073060000000055e-07

# %%
benchmark_results_merge.to_pickle("./benchmark_results_merge.pkl")

# %%
pd.read_pickle("./benchmark_results_merge.pkl")
# Out:
#    input ordering input size run number sorting algorithm          time
# 0   sorted         10         1          Merge Sort        1.654723e-05
# 1   sorted         10         2          Merge Sort        1.679397e-05
# 2   sorted         10         3          Merge Sort        1.594832e-05
# 3   sorted         10         4          Merge Sort        1.553654e-05
# 4   sorted         10         5          Merge Sort        1.557504e-05
# 5   sorted         100        1          Merge Sort        2.242792e-04
# 6   sorted         100        2          Merge Sort        2.227247e-04
# 7   sorted         100        3          Merge Sort        2.320079e-04
# 8   sorted         100        4          Merge Sort        2.231445e-04
# 9   sorted         100        5          Merge Sort        2.240668e-04
# 10  sorted         1000       1          Merge Sort        3.033693e-03
# 11  sorted         1000       2          Merge Sort        2.948484e-03
# 12  sorted         1000       3          Merge Sort        3.065751e-03
# 13  sorted         1000       4          Merge Sort        3.281447e-03
# 14  sorted         1000       5          Merge Sort        2.961653e-03
# 15  reversed       10         1          Merge Sort        1.655828e-05
# 16  reversed       10         2          Merge Sort        1.647050e-05
# 17  reversed       10         3          Merge Sort        1.647229e-05
# 18  reversed       10         4          Merge Sort        1.654939e-05
# 19  reversed       10         5          Merge Sort        1.685825e-05
# 20  reversed       100        1          Merge Sort        2.419428e-04
# 21  reversed       100        2          Merge Sort        2.322666e-04
# 22  reversed       100        3          Merge Sort        2.415619e-04
# 23  reversed       100        4          Merge Sort        2.326440e-04
# 24  reversed       100        5          Merge Sort        2.341681e-04
# 25  reversed       1000       1          Merge Sort        3.255430e-03
# 26  reversed       1000       2          Merge Sort        2.998437e-03
# 27  reversed       1000       3          Merge Sort        3.071281e-03
# 28  reversed       1000       4          Merge Sort        3.012556e-03
# 29  reversed       1000       5          Merge Sort        3.174741e-03
# 30  random         10         1          Merge Sort        2.970497e-05
# 31  random         10         2          Merge Sort        2.916003e-05
# 32  random         10         3          Merge Sort        2.918286e-05
# 33  random         10         4          Merge Sort        2.971740e-05
# 34  random         10         5          Merge Sort        2.920648e-05
# 35  random         100        1          Merge Sort        4.937100e-04
# 36  random         100        2          Merge Sort        4.749224e-04
# 37  random         100        3          Merge Sort        4.956440e-04
# 38  random         100        4          Merge Sort        4.797908e-04
# 39  random         100        5          Merge Sort        4.792110e-04
# 40  random         1000       1          Merge Sort        6.626854e-03
# 41  random         1000       2          Merge Sort        6.665484e-03
# 42  random         1000       3          Merge Sort        6.620930e-03
# 43  random         1000       4          Merge Sort        6.834996e-03
# 44  random         1000       5          Merge Sort        6.649702e-03
# 45  identical      10         1          Merge Sort        4.065902e-07
# 46  identical      10         2          Merge Sort        4.110512e-07
# 47  identical      10         3          Merge Sort        4.379530e-07
# 48  identical      10         4          Merge Sort        4.031226e-07
# 49  identical      10         5          Merge Sort        4.028762e-07
# 50  identical      100        1          Merge Sort        4.075452e-07
# 51  identical      100        2          Merge Sort        4.405124e-07
# 52  identical      100        3          Merge Sort        4.038488e-07
# 53  identical      100        4          Merge Sort        4.045646e-07
# 54  identical      100        5          Merge Sort        4.086674e-07
# 55  identical      1000       1          Merge Sort        4.073060e-07
# 56  identical      1000       2          Merge Sort        4.201456e-07
# 57  identical      1000       3          Merge Sort        4.078860e-07
# 58  identical      1000       4          Merge Sort        4.084970e-07
# 59  identical      1000       5          Merge Sort        4.220714e-07

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_merge, hue ='input ordering')

# %% [markdown]
# ### Benchmarking of python sort function

# %%
np.random.seed(12345)
benchmark_results_python = pd.DataFrame(columns =['input ordering','input size','run number','sorting algorithm','time'])

# %%
for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': sorted,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)  
        
        print(f"Python sort function minimum time on {input_ordering} data of size 10^{input_size}:", min(t)/n_ar)
        
        for run_number in range(5):
            benchmark_results_python = benchmark_results_python.append({'input ordering': input_ordering,
                                                          
                                                         'input size':10**input_size,
                                                          'run number':run_number+1,
                                                          'sorting algorithm':'Python Sort',
                                                          'time':t[run_number]/n_ar},
                                                             ignore_index=True)
# Out:
# Python sort function minimum time on sorted data of size 10^1: 6.804483999999889e-07
# Python sort function minimum time on sorted data of size 10^2: 2.8780719999998896e-06
# Python sort function minimum time on sorted data of size 10^3: 2.3746140000000084e-05
# Python sort function minimum time on reversed data of size 10^1: 6.851154000000008e-07
# Python sort function minimum time on reversed data of size 10^2: 2.842478999999969e-06
# Python sort function minimum time on reversed data of size 10^3: 2.3085110000000953e-05
# Python sort function minimum time on random data of size 10^1: 3.090200999999979e-06
# Python sort function minimum time on random data of size 10^2: 2.2706740000000993e-05
# Python sort function minimum time on random data of size 10^3: 0.0003068335000000104
# Python sort function minimum time on identical data of size 10^1: 4.155437999999947e-07
# Python sort function minimum time on identical data of size 10^2: 4.169636000000025e-07
# Python sort function minimum time on identical data of size 10^3: 3.9414000000002145e-07

# %%
benchmark_results_python.to_pickle("./benchmark_results_python.pkl")

# %%
pd.read_pickle("./benchmark_results_python.pkl")
# Out:
#    input ordering input size run number sorting algorithm          time
# 0   sorted         10         1          Python Sort       7.021598e-07
# 1   sorted         10         2          Python Sort       7.057922e-07
# 2   sorted         10         3          Python Sort       6.925886e-07
# 3   sorted         10         4          Python Sort       6.817014e-07
# 4   sorted         10         5          Python Sort       6.804484e-07
# 5   sorted         100        1          Python Sort       2.886214e-06
# 6   sorted         100        2          Python Sort       2.878072e-06
# 7   sorted         100        3          Python Sort       2.911855e-06
# 8   sorted         100        4          Python Sort       2.878497e-06
# 9   sorted         100        5          Python Sort       2.895289e-06
# 10  sorted         1000       1          Python Sort       2.394000e-05
# 11  sorted         1000       2          Python Sort       2.374614e-05
# 12  sorted         1000       3          Python Sort       2.388034e-05
# 13  sorted         1000       4          Python Sort       2.383796e-05
# 14  sorted         1000       5          Python Sort       2.380111e-05
# 15  reversed       10         1          Python Sort       6.862252e-07
# 16  reversed       10         2          Python Sort       6.897986e-07
# 17  reversed       10         3          Python Sort       6.866838e-07
# 18  reversed       10         4          Python Sort       6.875888e-07
# 19  reversed       10         5          Python Sort       6.851154e-07
# 20  reversed       100        1          Python Sort       2.842479e-06
# 21  reversed       100        2          Python Sort       2.847221e-06
# 22  reversed       100        3          Python Sort       2.874398e-06
# 23  reversed       100        4          Python Sort       2.859130e-06
# 24  reversed       100        5          Python Sort       2.935960e-06
# 25  reversed       1000       1          Python Sort       2.321080e-05
# 26  reversed       1000       2          Python Sort       2.308511e-05
# 27  reversed       1000       3          Python Sort       2.323038e-05
# 28  reversed       1000       4          Python Sort       2.310711e-05
# 29  reversed       1000       5          Python Sort       2.314059e-05
# 30  random         10         1          Python Sort       3.101326e-06
# 31  random         10         2          Python Sort       3.090201e-06
# 32  random         10         3          Python Sort       3.118346e-06
# 33  random         10         4          Python Sort       3.105515e-06
# 34  random         10         5          Python Sort       3.096293e-06
# 35  random         100        1          Python Sort       2.310953e-05
# 36  random         100        2          Python Sort       2.270674e-05
# 37  random         100        3          Python Sort       2.275605e-05
# 38  random         100        4          Python Sort       2.279176e-05
# 39  random         100        5          Python Sort       2.273288e-05
# 40  random         1000       1          Python Sort       3.068335e-04
# 41  random         1000       2          Python Sort       3.081056e-04
# 42  random         1000       3          Python Sort       3.411138e-04
# 43  random         1000       4          Python Sort       3.145547e-04
# 44  random         1000       5          Python Sort       3.338884e-04
# 45  identical      10         1          Python Sort       4.647472e-07
# 46  identical      10         2          Python Sort       4.729606e-07
# 47  identical      10         3          Python Sort       4.155438e-07
# 48  identical      10         4          Python Sort       4.158334e-07
# 49  identical      10         5          Python Sort       4.417026e-07
# 50  identical      100        1          Python Sort       4.542840e-07
# 51  identical      100        2          Python Sort       4.482808e-07
# 52  identical      100        3          Python Sort       4.169636e-07
# 53  identical      100        4          Python Sort       4.235330e-07
# 54  identical      100        5          Python Sort       4.338342e-07
# 55  identical      1000       1          Python Sort       4.475614e-07
# 56  identical      1000       2          Python Sort       4.312758e-07
# 57  identical      1000       3          Python Sort       4.102250e-07
# 58  identical      1000       4          Python Sort       3.973042e-07
# 59  identical      1000       5          Python Sort       3.941400e-07

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_python, hue ='input ordering')

# %% [markdown]
# ## Numpy Sort

# %%
def numpy_sort(data):
    return np.sort(data)

# %%
np.random.seed(12345)
benchmark_results_numpy = pd.DataFrame(columns =['input ordering','input size', 'sorting algorithm','time'])

# %%
list_min_times = []

for input_ordering in ['sorted','reversed','random','identical']:
    
    for input_size in range(1,4):
        
        test_data = np.random.random((10**input_size,))
        
        if input_ordering == 'sorted':
            test_data = sorted(test_data)
        
        elif input_ordering == 'reversed':
            test_data = list(reversed(sorted(test_data)))
        
        elif input_ordering == 'identical':
            test_data =  [test_data]*0
            
        clock = timeit.Timer(stmt='sort_func(copy(data))',
                     globals={'sort_func': numpy_sort,
                              'data': test_data,
                              'copy': copy.copy})
        n_ar, t_ar = clock.autorange()
        t = clock.repeat(repeat=5, number=n_ar)
        min_time = min(t)/n_ar
        list_min_times.append(min_time)
        
        print(f"Numpy sort function minimum time on {input_ordering} data of size 10^{input_size}:", min_time)
        
        benchmark_results_numpy = benchmark_results_numpy.append({'input ordering': input_ordering,
                                                     'input size':10**input_size,
                                                      'sorting algorithm':'NumPy-sort',
                                                      'time':min_time},
                                                         ignore_index=True)
# Out:
# Numpy sort function minimum time on sorted data of size 10^1: 4.66347600000006e-06
# Numpy sort function minimum time on sorted data of size 10^2: 1.0439904999999783e-05
# Numpy sort function minimum time on sorted data of size 10^3: 6.998141999999915e-05
# Numpy sort function minimum time on reversed data of size 10^1: 4.433303999999794e-06
# Numpy sort function minimum time on reversed data of size 10^2: 1.0595200000000205e-05
# Numpy sort function minimum time on reversed data of size 10^3: 7.2573060000002e-05

# %%
benchmark_results_numpy.to_pickle("./benchmark_results_numpy.pkl")

# %%
pd.read_pickle("./benchmark_results_numpy.pkl")

# %%
 ax = sns.lineplot(x="input size", y="time", data=benchmark_results_python, hue ='input ordering')

# %% [markdown]
# # Combined Dataframe

# %%
frames = [ benchmark_results_heap, benchmark_results_merge, benchmark_results_numpy, benchmark_results_python, benchmark_results_quick]

# %%
combined = pd.concat(frames, axis =0)

# %%
combined

# %% [markdown]
# # Plot for Sorted Data

# %%
df_sorted = combined[combined['input ordering'] == 'sorted']

# %%
df_sorted

# %%
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_sorted)

# %% [markdown]
# ## Plot for reversed data

# %%
df_reversed = combined[combined['input ordering'] == 'reversed']
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_reversed)

# %% [markdown]
# ## Plot for random data

# %%
df_random = combined[combined['input ordering'] == 'random']
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_random)

# %% [markdown]
# ## Plot for Identical data

# %%
df_identical = combined[combined['input ordering'] == 'identical']
sns.lineplot(x='input size', y='time', hue='sorting algorithm', data=df_identical)
